# %% [markdown]
# # 2023.11.30 - Introduction to RAG | Practical Part

# %% [markdown]
# #### Model without RAG

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# %% [markdown]
# ###### Download generation model

# %%
model_name = "allenai/unifiedqa-t5-small"

# %%
local_model_directory="." # mention the localtion where you want to save the model

# %%
model = AutoModelForSeq2SeqLM.from_pretrained("allenai/unifiedqa-t5-small")
model.save_pretrained("local_model_directory")

# %%
tokenizer = AutoTokenizer.from_pretrained("allenai/unifiedqa-t5-small")
tokenizer.save_pretrained("local_model_directory")

# %% [markdown]
# ###### Load model from disk

# %%
# Load local model
model = AutoModelForSeq2SeqLM.from_pretrained("local_model_directory").to("mps") # Move to M1 GPU
tokenizer = AutoTokenizer.from_pretrained("local_model_directory")
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %% [markdown]
# ###### Generation

# %%
def generate(prompt):
    token_ids = tokenizer(prompt, return_tensors="pt").to("mps")
    generated_ids = model.generate(**token_ids)
    return tokenizer.batch_decode(generated_ids)

# %%
raw_prompt = "What did I eat on November 11th for dinner?"
generate(raw_prompt)
# Out:
# /Users/johannesoster/dev/InnovaticGroup/generative.at/ws23_generative_ai/.venv/lib/python3.11/site-packages/transformers/generation/utils.py:1260: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# ['<pad> dinner</s>']

# %% [markdown]
# #### What if we could augment our prompt with additional knowledge?

# %%
def get_augmented_promp(prompt, augmentation):
    return f"""
Context information: "{augmentation}".
Given the context information and not prior knowledge, answer the query.
Query: {prompt}
Answer: \
"""

# %%
augmentation = "on the 11th november i ate a lovely cheesecake for dinner"
augmented_prompt = get_augmented_promp(raw_prompt, augmentation)
augmented_prompt
# Out:
# '\nContext information: "on the 11th november i ate a lovely cheesecake for dinner".\nGiven the context information and not prior knowledge, answer the query.\nQuery: What did I eat on November 11th for dinner?\nAnswer: '

# %%
generate(augmented_prompt)
# Out:
# ['<pad> cheesecake</s>']

# %% [markdown]
# ### Retrival Augmented Generation: Step by Step

# %% [markdown]
# #### Data Ingestion

# %%
from sentence_transformers import SentenceTransformer
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %% [markdown]
# ###### Download Model

# %%
embd_model = SentenceTransformer("BAAI/bge-small-en-v1.5")

# %%
embd_model.save('./embd_model/')

# %% [markdown]
# ###### Load local model

# %%
embd_model = SentenceTransformer('./embd_model/')
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
# DB Store
raw_data = [
    "on the 11th november i ate a lovely cheesecake for dinner and a carrotte as a breakfast",
    "the second name of my ants second chicken is miranda",
    "the eiffel tower is located in south tirol."
]

# %%
# Create Embeddings
db= []
for chunk in raw_data:
    chunk_embd = embd_model.encode(chunk)
    node = {"embd": chunk_embd, "text": chunk}
    db.append(node)

db
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# [{'embd': array([-1.30421510e-02,  4.59370427e-02,  5.51192909e-02, -2.30988543e-02,
#          -3.15478933e-03,  2.48120166e-02,  6.08760454e-02,  5.93810342e-02,
#           5.84299723e-03,  3.28274327e-03,  2.70620483e-04, -3.16813253e-02,
#           2.53681242e-02,  5.53279556e-02,  2.66885404e-02, -1.70556773e-02,
#           4.59962562e-02, -6.20284900e-02, -1.35608807e-01, -5.65198669e-03,
#          -1.67642180e-02, -1.25390813e-02, -4.80024964e-02, -1.86989382e-02,
#           2.49041207e-02,  1.18087910e-01,  1.72056872e-02, -1.40382517e-02,
#          -6.39178678e-02, -1.02145687e-01,  2.56354809e-02,  9.60217975e-03,
#           6.13879599e-02, -5.61945923e-02, -5.04849851e-02,  8.65331793e-04,
#           1.31303845e-02,  5.91073111e-02, -4.39514890e-02,  4.12696786e-03,
#           9.64904577e-02, -1.74260139e-02,  4.07980867e-02, -1.01896785e-02,
#           2.15873439e-02, -1.91477723e-02, -3.92945670e-02,  3.70007604e-02,
#           9.23887193e-02,  9.75113828e-03, -2.54794974e-02,  6.45726472e-02,
#          -8.84479936e-03,  1.79820824e-02, -8.99295602e-03,  5.22017851e-02,
#          -3.85865569e-02,  1.24525176e-02,  4.58631404e-02,  1.87180936e-02,
#          -4.99161743e-02,  8.34885761e-02, -1.20435193e-01,  6.04353473e-02,
#          -8.78986716e-03,  1.42953976e-03, -6.39292151e-02, -2.34244727e-02,
#           3.93106453e-02,  5.37842177e-02, -9.92010906e-03,  3.05310655e-02,
#           6.52206764e-02,  3.62379029e-02,  4.48696502e-02, -3.63134407e-02,
#           2.52277609e-02,  1.51900854e-02, -5.45802601e-02,  5.31340837e-02,
#           1.72562134e-02,  4.43779528e-02,  2.07964499e-02, -1.85309909e-03,
#          -2.21284609e-02, -1.44149419e-02, -4.82145324e-02,  3.94543782e-02,
#           4.24847938e-02, -1.96523909e-02, -1.91473449e-03, -6.77101389e-02,
#          -4.63172421e-02,  3.80848013e-02, -1.73545890e-02, -8.16158717e-04,
#          -1.50443327e-06, -1.33914184e-02, -2.32082466e-03,  3.31671625e-01,
#          -3.25198397e-02, -3.59025109e-03,  8.50326661e-03,  1.28292460e-02,
#          -1.14216134e-02, -4.02927911e-03, -3.06618423e-03, -2.93898731e-02,
#          -1.76911652e-02, -4.91985381e-02,  9.00502224e-03, -2.66300663e-02,
#           7.31123015e-02, -2.71095778e-03,  3.19455713e-02,  2.82491427e-02,
#           4.94675562e-02,  1.22096883e-02, -2.20692288e-02,  5.22388443e-02,
#          -2.60613225e-02,  6.39430508e-02, -5.76565415e-03,  1.51559729e-02,
#          -3.41042802e-02,  6.40385151e-02,  7.97262490e-02,  4.57387306e-02,
#          -7.39517286e-02,  4.90928143e-02, -2.09864564e-02,  1.25763379e-02,
#           1.72603037e-02, -2.07058433e-02,  5.73400557e-02,  4.06508818e-02,
#           5.15604839e-02, -7.23694563e-02,  3.08282580e-02, -6.85709193e-02,
#          -4.83478010e-02, -1.33511513e-01,  1.30771445e-02, -2.08665859e-02,
#           7.01322332e-02,  1.09526897e-02,  4.69254702e-02,  2.81849243e-02,
#          -1.50894905e-02,  3.16883326e-02,  4.73267324e-02, -3.53675941e-03,
#          -2.38159741e-03, -3.29200774e-02, -4.90239076e-02,  3.52370366e-03,
#           4.19938192e-02,  4.36400995e-04,  5.07199243e-02, -1.17476610e-02,
#          -2.22345497e-02, -4.89089638e-02,  5.09935431e-03, -8.70278925e-02,
#           1.13919359e-02, -1.24569841e-01, -3.19127776e-02,  4.10623997e-02,
#           1.85710788e-02, -6.15130411e-04,  5.25313467e-02,  8.50130245e-03,
#          -2.79018041e-02, -3.28961052e-02,  9.93134901e-02, -2.47282404e-02,
#           6.23833872e-02,  7.16008544e-02, -2.53368597e-02, -2.97578430e-04,
#           5.78252301e-02, -1.98998731e-02,  1.86995100e-02,  2.51956806e-02,
#           1.09741855e-02,  1.44515727e-02, -7.60865025e-03, -1.01903891e-02,
#          -1.94361918e-02,  2.78740060e-02, -2.28327885e-02, -1.66785140e-02,
#          -7.29299113e-02,  1.26637518e-02, -5.04001118e-02, -1.43691991e-02,
#           8.38715874e-04,  4.33016233e-02, -1.79843027e-02,  4.73194942e-03,
#          -2.33920719e-02, -1.06379084e-01,  1.24690253e-02, -1.76033638e-02,
#           6.81373775e-02, -6.51434138e-02, -2.64885630e-02, -1.85991321e-02,
#           5.63256033e-02,  4.88640321e-03,  1.36992494e-02, -2.54648291e-02,
#           5.77839054e-02,  6.50893291e-03, -3.45259048e-02, -7.43005611e-03,
#           2.84798518e-02,  4.46498245e-02, -3.49183157e-02, -3.17237116e-02,
#           6.36076033e-02, -1.20837212e-01, -3.03393956e-02, -2.38962829e-01,
#          -4.25808430e-02,  3.74182984e-02, -6.05870821e-02, -3.99661399e-02,
#          -6.59457147e-02, -2.55083703e-02, -1.79144200e-02, -2.20453870e-02,
#          -2.80677509e-02,  8.79688635e-02,  6.34780079e-02, -3.38803306e-02,
#           2.40719598e-02,  2.74461042e-02,  2.74483878e-02,  4.29967642e-02,
#          -4.24832255e-02,  2.67111650e-03, -2.32825689e-02, -7.56052928e-03,
#          -4.18922380e-02,  1.23329880e-02, -1.18404739e-02, -9.97377560e-04,
#          -2.71759592e-02,  1.54858872e-01,  8.98583233e-02, -3.18616033e-02,
#           2.09016725e-02,  7.35912612e-03, -4.66276833e-06,  4.41823006e-02,
#          -1.60292506e-01,  1.39819821e-02,  2.28303410e-02,  1.08891062e-01,
#          -1.79315805e-02, -2.37307865e-02, -3.53696533e-02, -1.84054412e-02,
#          -3.25710960e-02, -2.21070461e-02, -1.09996021e-01, -5.06451577e-02,
#           5.33157494e-03, -2.34015267e-02, -2.88119018e-02,  5.83528019e-02,
#           5.69883734e-02, -4.06226236e-03,  1.61797251e-03, -2.17212476e-02,
#          -1.97739732e-02, -1.34771001e-02,  5.66876568e-02, -4.61887121e-02,
#          -2.49152891e-02, -5.01038646e-03,  5.18294908e-02, -2.21853964e-02,
#          -2.33627111e-02, -6.95027690e-03, -2.55622584e-02,  2.65429597e-02,
#           2.39783954e-02, -5.03803231e-02, -3.85060608e-02, -3.88659164e-02,
#           9.10750404e-02, -2.89980527e-02, -1.14072170e-02, -6.78912411e-03,
#          -5.94679452e-02,  4.67933267e-02,  4.30261455e-02, -1.59490909e-02,
#           3.73408273e-02,  5.79286478e-02, -3.64450365e-02, -3.43676805e-02,
#          -9.10241809e-03,  4.03797962e-02,  4.59508831e-03, -4.51641099e-04,
#          -4.61013764e-02,  3.61636095e-02, -4.44728099e-02,  3.00430972e-02,
#          -1.49843032e-02, -3.45493504e-03, -2.85736322e-02, -6.53317049e-02,
#           4.17805314e-02,  5.45168519e-02,  4.24514748e-02, -2.43294686e-01,
#           1.15571566e-01, -7.17609227e-02,  9.86444671e-03,  4.72022854e-02,
#          -1.10554500e-02, -1.78284124e-02,  3.39289457e-02, -1.31852746e-01,
#           3.14198472e-02,  7.34438300e-02,  2.84285081e-04,  4.60865535e-02,
#          -2.93492973e-02,  4.64497618e-02,  1.01333112e-02, -7.47740865e-02,
#          -1.47533175e-02, -2.42140740e-02, -5.85954189e-02, -4.69898768e-02,
#           1.93057656e-02,  1.27633467e-01,  3.10175568e-02, -5.31587936e-02,
#          -2.10950524e-02,  4.85328883e-02,  3.11191138e-02, -2.07239240e-02,
#           1.01054450e-02, -1.31914122e-02, -2.32547019e-02, -2.84536295e-02,
#          -1.85594987e-02, -2.54152622e-02,  1.18250195e-02,  2.55239811e-02,
#           2.35450733e-02,  2.10948773e-02,  1.98818482e-02, -2.61235554e-02,
#          -2.46873982e-02, -3.71534564e-02, -3.46640348e-02,  6.28206655e-02,
#          -7.09003359e-02,  7.96458684e-03, -6.89959824e-02,  5.58907948e-02,
#          -6.74494579e-02,  1.02098025e-01, -2.52426788e-02, -4.05973047e-02,
#           1.31998705e-02,  1.80505831e-02, -2.04800740e-02, -5.25215529e-02,
#           1.08246494e-03,  5.62892808e-03,  1.61625054e-02,  5.74708395e-02,
#           6.50467072e-03,  1.78281181e-02,  1.58763435e-02, -4.63534817e-02],
#         dtype=float32),
#   'text': 'on the 11th november i ate a lovely cheesecake for dinner and a carrotte as a breakfast'},
#  {'embd': array([-2.60280930e-02, -7.94524848e-02, -2.05439841e-03, -9.19680949e-03,
#           2.26203594e-02,  2.19576657e-02,  7.27279261e-02,  5.89132048e-02,
#           7.02864230e-02, -2.57384367e-02,  1.43602230e-02, -8.34894553e-02,
#           9.02911462e-03, -6.51293201e-03,  3.42040043e-03, -2.54421798e-03,
#          -2.18893904e-02,  4.79646884e-02, -1.05486609e-01, -1.38813416e-02,
#          -3.54246944e-02, -7.44820610e-02, -6.87112275e-04, -5.25416173e-02,
#          -7.33769592e-03,  8.47914591e-02,  8.79849494e-03,  7.50520006e-02,
#          -6.33902401e-02, -1.37824357e-01, -3.93384919e-02,  1.83672775e-02,
#          -5.44400187e-03,  1.36002200e-02, -4.66955174e-03,  1.75169092e-02,
#          -1.79740377e-02,  1.47552614e-03, -2.21779346e-02,  7.75485951e-03,
#           4.23805080e-02, -5.48126213e-02,  2.68009212e-02, -5.58991032e-03,
#          -7.13968257e-05, -6.79340661e-02, -6.11097850e-02, -3.80952470e-02,
#           5.50504923e-02, -2.94445548e-02, -5.51351765e-03,  1.26135089e-02,
#          -3.58266197e-02,  6.16606213e-02,  1.36167405e-03,  4.92075123e-02,
#           4.09284793e-03,  3.32869701e-02,  1.82440260e-03,  2.38336772e-02,
#          -7.14531774e-03,  3.53277139e-02, -1.32001683e-01,  8.76371786e-02,
#          -1.12549635e-02, -3.51738706e-02, -3.47522162e-02, -2.87615657e-02,
#          -5.64776435e-02,  5.31329177e-02,  2.38303058e-02,  2.95430608e-02,
#           1.22237997e-02,  3.80623452e-02,  3.85853508e-03,  3.83836441e-02,
#           5.74109424e-03,  7.89790042e-03,  3.07489913e-02,  5.23216836e-03,
#          -5.01831323e-02, -1.70626733e-02,  2.27067573e-03, -3.24400999e-02,
#          -1.67290829e-02,  2.66708490e-02,  1.49589789e-03, -3.09481118e-02,
#           3.99908870e-02, -2.42007356e-02,  1.42517136e-02, -1.84636600e-02,
#           6.99595809e-02, -2.87861824e-02, -7.67144263e-02,  7.50703458e-03,
#          -7.76250735e-02, -1.61827281e-02,  1.86124519e-02,  3.52770269e-01,
#           1.76372454e-02,  2.32993392e-03,  2.82093771e-02,  4.57214937e-03,
#           5.23234531e-02, -6.59489334e-02,  6.00666460e-03, -3.27763408e-02,
#          -1.18229620e-03,  9.36290547e-02,  2.75730696e-02,  1.44995470e-02,
#           2.63268892e-02, -3.90398689e-03, -1.11687882e-02,  1.66117530e-02,
#           3.75208557e-02, -3.98975089e-02,  3.06706852e-03,  9.91736166e-03,
#           4.07130606e-02, -5.66966124e-02,  5.07027209e-02, -1.82712190e-02,
#           3.55979949e-02, -2.82945316e-02,  4.13677171e-02,  7.30735287e-02,
#          -3.63950469e-02, -2.50987262e-02,  7.13568330e-02, -3.34911607e-02,
#           4.87069562e-02, -1.72769781e-02,  4.27231602e-02,  2.10283371e-03,
#           2.51698997e-02, -9.45342518e-03,  2.87828525e-03, -4.98972312e-02,
#          -4.34333794e-02, -1.33797601e-01, -3.54031730e-03, -4.22230177e-02,
#           1.43558672e-02,  4.55477387e-02, -2.53767404e-03, -1.61276404e-02,
#          -4.69887182e-02,  9.22702178e-02, -3.41540016e-02,  5.27696535e-02,
#           3.87136713e-02, -3.93057335e-03,  1.82467867e-02, -1.43088978e-02,
#           5.61907068e-02,  9.66918990e-02,  2.09914781e-02, -3.45702581e-02,
#           5.92163019e-02, -3.92197371e-02, -2.21300591e-02,  3.33465450e-02,
#           7.62658706e-03, -9.46740434e-02, -3.66169289e-02,  6.25263602e-02,
#           5.56849390e-02,  2.68556867e-02,  8.89700353e-02, -8.50700960e-03,
#          -5.98118454e-02, -4.10443693e-02,  3.47824465e-03, -2.25378051e-02,
#          -6.95990473e-02, -3.51514295e-02,  9.93727334e-03,  6.48964487e-04,
#          -1.83106512e-02, -4.56640311e-02, -1.03066526e-02,  3.68430130e-02,
#          -8.92456993e-03, -2.68368926e-02, -1.09080831e-02, -2.26936508e-02,
#           3.04921228e-03, -2.55684387e-02,  3.84812616e-02,  6.78391531e-02,
#           3.94329391e-02,  2.62889899e-02, -4.11144197e-02, -4.57925349e-02,
#           5.74835986e-02,  4.05126326e-02,  1.17780827e-02, -6.23659752e-02,
#           3.31744105e-02, -5.80020398e-02,  4.88663092e-02,  4.18605432e-02,
#           3.54344100e-02,  3.06101586e-03,  7.09610507e-02,  8.79316684e-03,
#           7.58661237e-03,  1.83086339e-02,  3.05058677e-02, -2.20074877e-02,
#          -1.19720036e-02, -3.50957550e-02, -4.89240102e-02,  1.17961176e-01,
#          -9.84557625e-03, -2.88549270e-02,  8.25633928e-02,  2.46726684e-02,
#           4.00359184e-02, -2.27480498e-03, -4.76100855e-03, -3.05383563e-01,
#          -7.60717876e-03, -7.22517213e-03, -6.79392293e-02, -3.95060368e-02,
#          -3.58548202e-02,  2.39602178e-02, -2.55949236e-02,  8.30973685e-02,
#          -3.86131667e-02, -7.55896466e-03, -1.14069590e-02,  1.10614905e-03,
#           5.91335520e-02, -3.14318687e-02,  1.04566179e-01,  8.09239149e-02,
#           4.17952538e-02,  7.08882045e-03,  3.90001982e-02, -6.29405398e-03,
#           2.03523040e-03,  4.72411290e-02, -2.08614245e-02,  1.48340426e-02,
#           3.37807909e-02,  1.31670475e-01,  1.40191004e-01, -4.39518457e-03,
#           5.40854596e-03,  5.59536628e-02,  2.25081258e-02,  4.43451069e-02,
#          -1.06339408e-02, -6.09003147e-03,  3.00219981e-03, -6.15684548e-03,
#          -4.77776565e-02, -2.17792168e-02, -3.54786664e-02, -3.30074728e-02,
#          -7.06620561e-03,  6.20845379e-03, -3.79499532e-02,  2.08617076e-02,
#          -1.57051012e-02,  1.33336326e-02, -5.13783377e-03,  5.07413968e-03,
#          -1.57073401e-02, -6.02104887e-03,  9.56295505e-02, -6.21635392e-02,
#          -2.84811575e-02,  3.31479521e-03,  4.10367921e-02, -1.43130671e-03,
#          -1.30691221e-02, -1.46521544e-02,  8.50504451e-03, -3.46149765e-02,
#          -3.53978314e-02,  1.55617995e-02, -5.22720329e-02,  6.24789798e-04,
#          -1.75345074e-02, -2.96599660e-02, -1.01397624e-02, -3.87423262e-02,
#           2.98770354e-03, -3.25950375e-03,  1.68319624e-02, -5.61538036e-04,
#          -2.06358749e-02,  1.81063749e-02, -6.22842759e-02,  3.94152105e-03,
#          -5.12369461e-02, -5.18486015e-02,  1.38301356e-02,  3.12593617e-02,
#          -6.30880753e-03,  5.04540242e-02,  1.12069007e-04,  4.06989790e-02,
#           2.26223022e-02,  1.80452541e-02,  1.88047606e-02,  7.85100237e-02,
#          -6.10099360e-02, -4.62771161e-03,  2.21533086e-02, -3.19175050e-02,
#           2.06299182e-02,  1.32104261e-02,  1.64594073e-02, -2.66280770e-01,
#           2.86456198e-02,  8.69898871e-03,  1.03832902e-02, -5.23357047e-03,
#           1.03326794e-02, -2.36816630e-02, -3.68787870e-02, -1.79895777e-02,
#          -3.09132747e-02,  3.33867669e-02,  6.55298755e-02,  2.92100478e-02,
#           2.47850344e-02, -1.74209848e-02,  3.84328067e-02, -1.00262715e-02,
#           3.48669407e-03, -4.88383248e-02, -7.19224885e-02, -2.96541844e-02,
#          -7.37922490e-02,  1.72242612e-01,  3.23355012e-02, -5.60117289e-02,
#          -1.11379223e-02, -6.31616190e-02,  6.02741465e-02, -4.68352102e-02,
#          -9.78286937e-03,  3.87367122e-02, -1.21300798e-02, -1.38263544e-02,
#          -7.43622482e-02,  4.71890122e-02,  8.76189023e-03, -1.00291744e-01,
#           2.73378356e-03,  4.78091054e-02, -1.66154206e-02, -4.22320999e-02,
#           3.28959972e-02, -9.46826860e-02, -8.68565962e-03,  9.77038220e-02,
#          -4.66334112e-02,  1.19558524e-03, -1.90815644e-03, -7.64490711e-03,
#           4.86234501e-02, -5.01360148e-02, -8.76489356e-02, -3.25413309e-02,
#          -6.07403414e-03, -4.28201444e-02, -2.93931812e-02,  6.84582582e-03,
#          -2.36474760e-02,  1.49239926e-02, -2.84691546e-02,  3.18487100e-02,
#           1.99225079e-02,  6.18167520e-02, -1.67956688e-02,  5.81111312e-02],
#         dtype=float32),
#   'text': 'the second name of my ants second chicken is miranda'},
#  {'embd': array([-9.77511797e-03,  5.08099655e-03,  1.97648015e-02, -6.91028759e-02,
#           3.67132574e-02,  1.96911097e-02, -1.06978221e-02,  1.75925177e-02,
#          -4.20704260e-02, -3.92108820e-02, -1.23065552e-02, -1.64989159e-02,
#           1.07686538e-02,  5.30927116e-03, -3.18496339e-02,  1.24288518e-02,
#          -2.76845898e-02, -5.26016504e-02, -6.19399697e-02,  4.94871140e-02,
#          -2.89008080e-04, -5.43391854e-02,  3.02437153e-02, -2.39056982e-02,
#           1.70407183e-02,  5.64534776e-02, -2.14199778e-02,  4.85995524e-02,
#          -8.86958987e-02, -4.91644852e-02,  2.56457478e-02, -3.07083037e-02,
#          -4.69793333e-03, -2.06759181e-02, -1.53271733e-02, -1.78485308e-02,
#          -1.46045061e-02,  2.64016241e-02,  2.49867402e-02, -1.73406326e-03,
#           2.32109632e-02,  1.08694732e-02,  1.31402351e-02, -5.87471388e-02,
#           1.55005557e-02,  2.61568446e-02, -8.73826537e-03,  4.49892431e-02,
#          -2.45019533e-02, -1.02059215e-01, -1.02171879e-02,  4.64339219e-02,
#          -1.40820630e-02,  2.79935151e-02, -1.40237687e-02,  1.62129756e-02,
#           2.98953913e-02,  1.01518221e-02, -2.69144326e-02, -4.39698026e-02,
#           3.05515751e-02, -2.97583491e-02, -1.70481965e-01,  5.07818349e-03,
#          -3.04357242e-02,  1.64746996e-02,  1.78814270e-02,  3.95045243e-03,
#           5.73201571e-03, -1.65370330e-02,  3.91985662e-02,  5.47357164e-02,
#           1.04551129e-02,  2.72189807e-02,  3.83487381e-02,  2.92186011e-02,
#          -2.47725639e-02, -3.31099406e-02, -4.17322293e-02, -3.78411040e-02,
#           8.53695720e-02, -2.64221672e-02, -7.45759457e-02,  3.70113291e-02,
#          -3.52576263e-02,  2.19819434e-02, -4.71411683e-02, -2.88851466e-02,
#           3.80154401e-02,  6.08794577e-02,  2.00853013e-02, -4.68336195e-02,
#          -9.59129911e-03,  7.44808689e-02, -2.91795600e-02, -4.69314605e-02,
#          -2.04671565e-02,  5.18671647e-02,  3.43309529e-02,  3.06104839e-01,
#          -4.27319929e-02,  6.05544224e-02,  5.94662838e-02,  2.92885154e-02,
#           1.54527277e-02, -5.40309846e-02,  7.79092219e-03,  4.04590853e-02,
#          -6.82141259e-02,  2.26813592e-02, -6.23159893e-02, -7.74070024e-02,
#           3.68424207e-02, -7.33450130e-02,  1.21126827e-02, -1.30319502e-02,
#           1.40927788e-02, -3.15213799e-02, -8.83571953e-02, -6.42721951e-02,
#           4.01637852e-02,  2.15551234e-03,  5.51034650e-03, -9.79014090e-04,
#           1.55915050e-02,  4.98358868e-02,  5.99654987e-02,  6.00430332e-02,
#           5.22347130e-02, -4.19428665e-03, -6.52758451e-03,  3.78523432e-02,
#           2.73589347e-03,  2.62191631e-02, -5.48392870e-02,  4.56200428e-02,
#           1.62425509e-03, -3.39124985e-02,  3.14384624e-02, -7.29267485e-03,
#          -1.93870906e-03, -6.11642562e-02,  3.14304493e-02, -8.66860375e-02,
#           1.80584714e-02,  7.17593804e-02,  1.57239828e-02, -8.79151449e-02,
#          -2.61543342e-03, -2.98575684e-02,  2.61457805e-02,  4.73773926e-02,
#           2.39956956e-02,  7.18940049e-02,  2.89370975e-04,  7.62664899e-02,
#          -2.85219215e-02,  9.72392261e-02,  3.27982493e-02, -5.71839549e-02,
#          -4.97666299e-02,  2.39459015e-02, -6.06293678e-02,  9.87512320e-02,
#           2.62073837e-02, -1.31335944e-01, -2.53495667e-02,  1.06700119e-02,
#           1.16801355e-02, -6.93573356e-02, -3.63065675e-02,  2.72964546e-03,
#          -5.11995107e-02,  4.45685238e-02,  6.56235516e-02,  3.05159688e-02,
#          -7.04562142e-02,  3.91622111e-02, -1.51818935e-02, -6.62875921e-02,
#           1.61231160e-02,  3.23904529e-02, -9.13648773e-03, -2.50148810e-02,
#          -1.24171628e-02,  5.68778545e-04,  4.50838618e-02, -7.23064169e-02,
#           2.63361968e-02,  4.81834114e-02, -2.27355510e-02,  1.20386168e-01,
#           7.54594803e-04, -1.14723938e-02,  1.71854310e-02,  7.52474007e-04,
#           7.00644357e-03,  6.04223274e-03,  4.22715582e-02,  3.19288261e-02,
#           4.89486493e-02, -7.79635366e-03, -4.25094850e-02,  2.20914241e-02,
#          -1.61284469e-02,  3.38374935e-02,  6.37570582e-03,  3.96225005e-02,
#          -5.95160015e-02,  2.07267292e-02,  2.76392475e-02,  2.11287551e-02,
#           1.05235569e-01, -2.49994993e-02,  1.26079591e-02,  1.37196258e-02,
#          -4.61626537e-02, -9.27379951e-02, -8.86248238e-03, -4.92421724e-02,
#           7.79474229e-02, -5.56886308e-02, -3.69313806e-02, -2.47972101e-01,
#          -3.69237810e-02, -4.92292084e-02, -3.85989435e-02, -1.74784090e-03,
#           1.81772579e-02, -1.09670255e-02, -4.29821014e-02,  2.62410268e-02,
#           8.32607783e-03,  4.90633361e-02, -5.58615364e-02,  7.38729024e-03,
#           6.29403666e-02, -2.89958548e-02,  7.20822997e-03,  1.97254959e-02,
#          -6.23447187e-02, -2.81134676e-02, -7.87605643e-02, -3.06925678e-04,
#           1.90702677e-02, -6.68650940e-02,  2.47835666e-02,  6.59119636e-02,
#          -4.12380956e-02,  1.38643548e-01,  2.80207694e-02,  1.25183677e-02,
#          -4.33790721e-02, -3.53875197e-02,  9.33247991e-03,  2.19246577e-02,
#          -4.68894877e-02,  2.84695365e-02, -5.11194253e-03,  1.36479780e-01,
#          -1.70127843e-02, -1.90032739e-03,  1.64188519e-02,  7.62133449e-02,
#           6.68880120e-02,  7.22152600e-03, -4.83402275e-02, -4.09813374e-02,
#           1.39309820e-02,  3.36011685e-02,  7.07793757e-02, -5.43447249e-02,
#          -1.54680386e-02,  1.42945927e-02, -2.21554022e-02,  3.36407684e-02,
#          -2.16119047e-02,  6.63491338e-02,  2.67570913e-02, -3.59544940e-02,
#          -1.30818794e-02, -1.35912551e-02,  3.32307480e-02, -4.56966609e-02,
#           3.75427082e-02,  7.23570911e-03, -1.86820421e-02,  1.93000883e-02,
#           6.51441216e-02, -2.18960475e-02, -1.05763124e-02,  5.53667305e-05,
#           1.82940345e-02,  1.27472244e-02,  4.18640785e-02, -2.32555494e-02,
#          -2.25227382e-02, -5.63751324e-04,  3.12617347e-02,  7.04383403e-02,
#           3.15470733e-02,  4.62509617e-02,  3.96095514e-02,  5.12597449e-02,
#          -3.22379768e-02,  8.62120464e-03,  1.23229995e-02, -1.53565984e-02,
#          -2.34645102e-02,  6.06554449e-02,  1.49598708e-02, -5.99606410e-02,
#          -2.22759843e-02, -5.35119027e-02, -5.70016867e-03,  7.45005999e-03,
#           1.32181821e-02, -4.10149582e-02, -1.40127940e-02, -3.03165048e-01,
#           5.09203132e-03,  8.19442701e-03,  3.47940065e-02,  4.59405594e-02,
#          -9.42196883e-03, -4.10383828e-02,  6.32017776e-02, -2.12558154e-02,
#          -4.46918830e-02,  5.78683726e-02, -7.91311264e-02,  3.23150717e-02,
#           4.14079838e-02, -7.27728531e-02, -2.02628896e-02, -2.22684555e-02,
#           2.14219559e-02,  6.47575781e-02,  2.83093732e-02, -5.62946014e-02,
#           7.64982402e-02,  1.29235744e-01, -3.82122509e-02,  3.45691363e-03,
#           1.99742727e-02, -8.52453858e-02,  6.16828958e-03, -7.31203556e-02,
#           5.92454933e-02, -1.47430897e-02, -5.49264299e-03, -6.78422749e-02,
#          -3.78125086e-02, -2.96887774e-02,  1.38460800e-01, -3.49146277e-02,
#           1.14932572e-02, -5.91263920e-03, -1.45052634e-02, -4.16356847e-02,
#           6.31274953e-02,  3.93830575e-02, -4.05506417e-02,  7.54047036e-02,
#          -9.17675197e-02,  3.02059744e-02,  6.15772530e-02,  5.31589985e-02,
#           3.65381804e-03,  1.35449534e-02, -1.74240321e-02, -6.99391263e-03,
#           2.35080998e-02, -6.60343096e-03,  1.81194674e-02, -8.99151526e-03,
#          -2.07459945e-02,  3.70074287e-02,  6.03942126e-02, -7.77840093e-02,
#          -1.51145207e-02, -6.21433146e-02, -1.56285781e-02,  7.00103790e-02],
#         dtype=float32),
#   'text': 'the eiffel tower is located in south tirol.'}]

# %% [markdown]
# #### Retrieval

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# %%
prompt = "What is the second name of my ants second chicken?"

# %%
prompt_embd = embd_model.encode(prompt)

# %%
def calculate_similarity(vec1, vec2):
    vec1 = np.array(list(vec1)).reshape(1, -1)
    vec2 = np.array(list(vec2)).reshape(1, -1)
    return cosine_similarity(vec1, vec2)[0][0]

# %%
similarities = [calculate_similarity(node.get('embd'), prompt_embd) for node in db]
most_similar_node = db[np.argmax(similarities)]
augemntation_data = most_similar_node.get('text')
augemntation_data
# Out:
# 'the second name of my ants second chicken is miranda'

# %% [markdown]
# #### Augmented

# %%
def get_augmented_promp(prompt, augmentation):
    return f"""
Context information: "{augmentation}".
Given the context information and not prior knowledge, answer the query.
Query: {prompt}
Answer: \
"""

# %%
augmented_prompt = get_augmented_promp(prompt, augemntation_data)
augmented_prompt
# Out:
# '\nContext information: "the second name of my ants second chicken is miranda".\nGiven the context information and not prior knowledge, answer the query.\nQuery: What is the second name of my ants second chicken?\nAnswer: '

# %% [markdown]
# ### Generation

# %%
generate(augmented_prompt)
# Out:
# /Users/johannesoster/dev/InnovaticGroup/generative.at/ws23_generative_ai/.venv/lib/python3.11/site-packages/transformers/generation/utils.py:1260: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# ['<pad> miranda</s>']
